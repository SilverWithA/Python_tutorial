# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ## 박스 플롯
#
# * 데이터의 요약수치를 사용하여 그린 plot으로 이상치 확인에 활용
#
# <b>`* plt.boxplot(data)`</b>
#
#
# `showmeans` = 평균표시
#
# `meanline`=True
#
# `vert`=False - 수평 박스 플롯

# %%
import seaborn as sns

iris = sns.load_dataset('iris')

plt.boxplot(iris['sepal_length'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x15b803db940>,
#   <matplotlib.lines.Line2D at 0x15b803dbbe0>],
#  'caps': [<matplotlib.lines.Line2D at 0x15b803dbe80>,
#   <matplotlib.lines.Line2D at 0x15b80410160>],
#  'boxes': [<matplotlib.lines.Line2D at 0x15b803db6a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x15b80410400>],
#  'fliers': [<matplotlib.lines.Line2D at 0x15b804106a0>],
#  'means': []}

# %%
plt.boxplot(iris['sepal_length'],showmeans=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x15b8047ba90>,
#   <matplotlib.lines.Line2D at 0x15b8047bd30>],
#  'caps': [<matplotlib.lines.Line2D at 0x15b8047bfd0>,
#   <matplotlib.lines.Line2D at 0x15b804a42b0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x15b8047b7f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x15b804a4550>],
#  'fliers': [<matplotlib.lines.Line2D at 0x15b804a4a90>],
#  'means': [<matplotlib.lines.Line2D at 0x15b804a47f0>]}

# %% [markdown]
# ### 이상치 구하기
#
#
# * 1/4 지점의 값 : 시리즈.quantile(.25)
# * 3/4 지점의 값 : 시리즈.quantile(.75)
# * 이상치<br>
# 1/4 지점의 값 - 1.5 * 사분위수 범위<br>
# 3/4 지점의 값 + 1.5 * 사분위수 범위<br>

# %%
scores = pd.Series([0,10,15,15,15,16,19,20,21,25,25,26,26,29,30,35,36,37,39,40,41,41,44,45,45,45,45,47,
          50,50,50,50,51,51,51,53,54,55,55,56,60,61,62,62,63,64,65,65,65,65,66,66,66,66,66,
          67,68,68,69,70,70,70,70,70,70,70,70,71,71,71,71,71,72,72,72,72,73,74,74,74,75,75,
          76,76,76,77,77,77,77,78,78,78,78,78,79,79,79,79,80,80,80,80,80,80,81,81,81,82,82,
          85,85,85,88,88,89,90,90,90,93,93,95,95,95,97,100])

# %%
Q1 = scores.quantile(.25)
print('1/4 지점의 값 : ',Q1)

Q3 = scores.quantile(.75)
print('3/4 지점의 값 : ',Q3)

# 이상치
print('이상치:',Q1 - 1.5*(Q3-Q1),'미만')

# 3/4 지점의 값 + 1.5 * 사분위수 범위
print('이상치:',Q3 + 1.5*(Q3-Q1),'이상')
# Out:
# 1/4 지점의 값 :  50.0
# 3/4 지점의 값 :  78.0
# 이상치: 8.0 미만
# 이상치: 120.0 이상

# %%
plt.boxplot(scores)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x15b80510130>,
#   <matplotlib.lines.Line2D at 0x15b805103d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x15b80510670>,
#   <matplotlib.lines.Line2D at 0x15b80510910>],
#  'boxes': [<matplotlib.lines.Line2D at 0x15b80410be0>],
#  'medians': [<matplotlib.lines.Line2D at 0x15b80510bb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x15b80510e50>],
#  'means': []}

# %% [markdown]
# ### 여러 데이터 비교하기

# %%
plt.boxplot([ iris['sepal_length'], iris['sepal_width'], iris['petal_length'], iris['petal_width']    ]
           , labels=['sepal_length', 'sepal_width','petal_length','petal_width']
           , showmeans=True)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ### ---------------------------------------------------------------------------------------

# %% [markdown]
# ## 바이올린 플롯
#
#
# * plt.`violinplot`(data)
#
# * 최대값, 최소값, 평균값, 중간값 표시 가능
# `showextrema` `showmeans` `showmedians`
#
# * 분위수 지정
#
# `quantiles` = [0~1사이의 실수 `리스트`]

# %%
import numpy as np
arr = np.random.standard_normal(100) # 난수생성
df = pd.DataFrame(arr)


plt.violinplot(df)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x15b81bba3b0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x15b81bba290>,
#  'cmins': <matplotlib.collections.LineCollection at 0x15b81bba9b0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x15b81bbad10>}
